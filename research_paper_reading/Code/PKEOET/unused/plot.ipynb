# %%
import matplotlib.pyplot as plt
import numpy as np


c_num_list = []
pkeoet_enc_list = []
pkeoet_ptest_list = []
pkeoet_total_list = []
pkeet_enc_list = []
dt_list = []
pkeet_t_list = []

pkeoet_log = 'output/log1.txt'
dt_log = 'output/log_d.txt'
pkeet_log = 'output/pkeet_log.txt'

# %%
c_num_list = []
pkeoet_enc_list = []
pkeoet_ptest_list = []
pkeoet_total_list = []

with open(pkeoet_log, 'r') as f1:
    for line in f1.readlines():
        if line[0] != 'C':
            l = line.split('\t')[:-1]
            c_num_list.append(int(l[0].split('.')[0]))
            pkeoet_enc_list.append(float(l[1]))
            pkeoet_ptest_list.append(float(l[2]))
            pkeoet_total_list.append(float(l[3]))

len(c_num_list)
# Out:
# 906

# %%
dt_list = []
i = 0
with open(dt_log, 'r') as f2:
    for line in f2.readlines():
        if line[0] != 'V':
            l = line.split('\t')[:-1]
            num = int(l[0].split('.')[0])
            if num in c_num_list:
                pkeoet_total_list[i] += float(l[1])
                dt_list.append(float(l[1]))
                i += 1
len(dt_list)
# Out:
# 906

# %%
# c_num_list = []
pkeet_enc_list = []
pkeet_t_list = []

with open(pkeet_log, 'r') as f3:
    for line in f3.readlines():
        if line[0] != 'C':
            l = line.split('\t')[:-1]
            num = int(l[0].split('.')[0])
            if num in c_num_list:
                pkeet_enc_list.append(float(l[1]))
                pkeet_t_list.append(float(l[2]))

len(pkeet_t_list)
# Out:
# 906

# %%
pkeoet_total_list
# Out:
# [1.432566,
#  1.80495,
#  2.173257,
#  2.657082,
#  3.197426,
#  5.043096,
#  6.948803000000001,
#  8.865596,
#  12.614431,
#  16.196773999999998,
#  19.935763,
#  23.706839000000002,
#  27.452298,
#  31.140081000000002,
#  34.842571,
#  38.489343999999996,
#  42.11773,
#  45.786974,
#  49.475451,
#  53.19328,
#  56.816447000000004,
#  60.498716,
#  64.177792,
#  67.875162,
#  71.559473,
#  75.184445,
#  78.83060499999999,
#  82.619168,
#  86.245852,
#  89.91426999999999,
#  93.578363,
#  97.329972,
#  101.067315,
#  104.697998,
#  108.322241,
#  112.00043699999999,
#  115.775739,
#  119.484702,
#  123.26816000000001,
#  127.053773,
#  130.702383,
#  134.378222,
#  138.124391,
#  141.875368,
#  145.786566,
#  149.56823400000002,
#  153.672762,
#  157.392878,
#  161.13134,
#  164.79271500000002,
#  169.61267899999999,
#  174.329457,
#  178.258015,
#  182.80089800000002,
#  186.782959,
#  190.586518,
#  194.26574,
#  197.971678,
#  201.762134,
#  205.472284,
#  209.309954,
#  213.12015499999998,
#  216.722443,
#  220.406493,
#  224.295321,
#  228.022987,
#  231.648577,
#  235.420991,
#  239.18751899999998,
#  243.147701,
#  246.86468299999999,
#  261.135471,
#  269.603297,
#  277.208056,
#  282.465287,
#  289.696556,
#  295.73224600000003,
#  304.00874999999996,
#  308.62254399999995,
#  312.838469,
#  316.756418,
#  320.87975200000005,
#  324.97571100000005,
#  329.408952,
#  333.344154,
#  337.44210400000003,
#  341.237693,
#  345.039469,
#  348.91366800000003,
#  352.716459,
#  1007.881925,
#  1011.61148,
#  1015.3787530000001,
#  1019.020356,
#  1022.600141,
#  1026.205497,
#  1029.9149,
#  1033.569528,
#  1037.1936369999999,
#  1041.660471,
#  1045.489403,
#  1049.051015,
#  1052.78622,
#  1056.4130989999999,
#  1060.0048040000001,
#  1063.613526,
#  1067.260633,
#  1070.891524,
#  1074.501785,
#  1078.1690079999998,
#  1081.804837,
#  1085.471778,
#  1089.111772,
#  1092.701145,
#  1096.276299,
#  1099.969205,
#  1103.596421,
#  1107.385688,
#  1111.054753,
#  1114.642601,
#  1118.305719,
#  1121.958067,
#  1125.546161,
#  1129.1903,
#  1132.877417,
#  1136.51324,
#  1140.125796,
#  1143.7562739999998,
#  1147.548653,
#  1151.139183,
#  1154.704443,
#  1158.271228,
#  1161.856652,
#  1165.4524390000001,
#  1169.029139,
#  1172.736049,
#  1176.305741,
#  1179.996893,
#  1183.783496,
#  1187.31255,
#  1190.883707,
#  1194.512698,
#  1198.157751,
#  1201.7839410000001,
#  1205.3533579999998,
#  1209.049487,
#  1212.668572,
#  1216.362111,
#  1220.1373409999999,
#  1223.812468,
#  1227.336335,
#  1231.08347,
#  1235.380739,
#  1240.335542,
#  1243.990352,
#  1247.68011,
#  1251.377497,
#  1255.155181,
#  1259.1395699999998,
#  1262.809847,
#  1266.471019,
#  1270.151883,
#  1273.82438,
#  1277.474751,
#  1281.1197789999999,
#  1284.858098,
#  1288.404702,
#  1292.069047,
#  1295.706802,
#  1299.322142,
#  1302.9447109999999,
#  1306.517572,
#  1310.200831,
#  1313.859535,
#  1317.4452979999999,
#  1321.035787,
#  1324.7382830000001,
#  1328.5510069999998,
#  1332.513248,
#  1337.221563,
#  1340.996948,
#  1344.519832,
#  1348.102114,
#  1351.616497,
#  1355.818022,
#  1359.426698,
#  1363.096845,
#  1366.662209,
#  1370.647181,
#  1375.011949,
#  1379.6586579999998,
#  1383.2228109999999,
#  1386.794141,
#  1390.369215,
#  1393.973166,
#  1397.7106990000002,
#  1402.021659,
#  1406.1169889999999,
#  1410.6163960000001,
#  1414.530683,
#  1418.8039330000001,
#  1422.936053,
#  1426.6730949999999,
#  1431.2157519999998,
#  1434.940905,
#  1438.6182430000001,
#  1442.325504,
#  1446.196275,
#  1450.0865019999999,
#  1454.132933,
#  1458.022726,
#  1462.153056,
#  1465.774363,
#  1469.378635,
#  1473.088089,
#  1476.781847,
#  1480.4436249999999,
#  1484.1228350000001,
#  1488.008949,
#  1491.801948,
#  1495.45312,
#  1499.149762,
#  1503.0952300000001,
#  1506.898682,
#  1510.507549,
#  1514.0464780000002,
#  1517.704762,
#  1521.3033420000002,
#  1524.932824,
#  1528.5453169999998,
#  1532.257879,
#  1535.923706,
#  1539.5485239999998,
#  1543.137726,
#  1546.835868,
#  1550.5104529999999,
#  1554.072691,
#  1557.6307940000002,
#  1561.2891000000002,
#  1564.91465,
#  1568.548769,
#  1572.1974109999999,
#  1575.826799,
#  1579.5298990000001,
#  1583.134158,
#  1586.804827,
#  1590.536645,
#  1594.1863669999998,
#  1597.886333,
#  1601.551102,
#  1605.6179439999999,
#  1610.194487,
#  1614.160147,
#  1618.4044920000001,
#  1622.31032,
#  1625.894463,
#  1629.481516,
#  1633.207207,
#  1636.875097,
#  1640.5055770000001,
#  1644.225173,
#  1647.955758,
#  1651.621097,
#  1655.312841,
#  1658.8784950000002,
#  1662.532709,
#  1666.204473,
#  1669.803361,
#  1673.440779,
#  1677.173481,
#  1680.899812,
#  1684.625403,
#  1688.330835,
#  1691.983086,
#  1695.686721,
#  1699.2562679999999,
#  1702.889233,
#  1706.70866,
#  1710.352394,
#  1714.075832,
#  1717.729372,
#  1721.309794,
#  1725.1383389999999,
#  1728.702254,
#  1732.285489,
#  1735.9355839999998,
#  1739.6015559999998,
#  1743.270976,
#  1746.930181,
#  1750.689431,
#  1754.847475,
#  1758.481194,
#  1762.1780270000002,
#  1767.05405,
#  1771.551023,
#  1775.620221,
#  1779.339509,
#  1782.995253,
#  1786.801921,
#  1790.451848,
#  1794.011582,
#  1797.5475279999998,
#  1801.999578,
#  1805.862748,
#  1809.40199,
#  1813.012485,
#  1816.69637,
#  1820.3880120000001,
#  1823.9671660000001,
#  1827.4975359999999,
#  1831.05924,
#  1834.671991,
#  1838.312813,
#  1841.975257,
#  1845.5077930000002,
#  1849.1310059999998,
#  1852.688722,
#  1856.227985,
#  1859.851713,
#  1863.3757719999999,
#  1866.92515,
#  1870.52827,
#  1874.122373,
#  1877.720061,
#  1881.209496,
#  1884.805695,
#  1888.396718,
#  1892.070849,
#  1895.608228,
#  1899.04207,
#  1902.693516,
#  1906.190856,
#  1909.778676,
#  1913.315213,
#  1916.9107569999999,
#  1920.493882,
#  1923.9764650000002,
#  1927.573342,
#  1931.1256620000001,
#  1934.574549,
#  1938.178384,
#  1941.720954,
#  1945.2827809999999,
#  1948.83681,
#  1952.3752290000002,
#  1956.020683,
#  1959.6552350000002,
#  1963.33498,
#  1966.8507390000002,
#  1970.321209,
#  1973.940916,
#  1977.522881,
#  1981.127869,
#  1984.682959,
#  1988.3439130000002,
#  1991.878304,
#  1995.449581,
#  1999.0094319999998,
#  2002.59445,
#  2006.164035,
#  2009.711702,
#  2013.2664829999999,
#  2016.875962,
#  2020.469782,
#  2023.9944209999999,
#  2027.613026,
#  2031.175102,
#  2034.872522,
#  2038.384694,
#  2041.8101179999999,
#  2045.3457010000002,
#  2048.89792,
#  2052.395789,
#  2055.964058,
#  2059.58137,
#  2063.153141,
#  2066.737551,
#  2070.3242840000003,
#  2074.001149,
#  2077.640179,
#  2081.290588,
#  2084.90122,
#  2088.370726,
#  2092.060873,
#  2095.633406,
#  2099.188638,
#  2102.785976,
#  2106.3619289999997,
#  2109.992518,
#  2113.5178300000002,
#  2117.078123,
#  2120.647506,
#  2124.2934729999997,
#  2127.931831,
#  2131.488481,
#  2134.951242,
#  2138.5211329999997,
#  2142.046522,
#  2145.682551,
#  2149.2192649999997,
#  2152.7087030000002,
#  2156.245967,
#  2159.832672,
#  2163.374257,
#  2166.993731,
#  2170.4533659999997,
#  3317.961948,
#  3321.56924,
#  3325.087022,
#  3328.68113,
#  3332.344114,
#  3336.007845,
#  3339.6142109999996,
#  3343.217266,
#  3346.810774,
#  3350.4100019999996,
#  3354.031029,
#  3357.5996600000003]

# %%
x = np.array(c_num_list)
y_pkeoet_enc = np.array(pkeoet_enc_list)
y_pkeoet_pt = np.array(pkeoet_ptest_list)
y_pkeoet_total = np.array(pkeoet_total_list)
y_dt = np.array(dt_list)
y_pkeet_enc = np.array(pkeet_enc_list)
y_pkeet_t = np.array(pkeet_t_list)

plt.xlabel('Ciphertext Num')
plt.ylabel('Time')

# plt.plot(x, y_pkeoet_enc, color='green', label='Pkeoet Enc Time')
plt.plot(x, y_pkeoet_pt, color='green', label='Pkeoet PTest Time')
plt.plot(x, y_pkeoet_total, color='red', label='Pkeoet Total Time')
plt.plot(x, y_dt, color='orange', label='Pkeoet DTest Time')
# plt.plot(x, y_pkeet_enc, color='red', label='Pkeet Enc Time')
plt.plot(x, y_pkeet_t, color='skyblue', label='Pkeet Test Time')

plt.rcParams['figure.dpi'] = 200
plt.legend()
plt.show()

# %%
pkeoet_server_log = 'output/log_server.txt'
c_num_list = []
pkeoet_server_enc_list = []
pkeoet_server_ptest_list = []
pkeoet_server_total_list = []

with open(pkeoet_server_log, 'r') as f1:
    for line in f1.readlines():
        if line[0] != 'C':
            l = line.split('\t')[:-1]
            c_num_list.append(int(l[0].split('.')[0]))
            pkeoet_server_enc_list.append(float(l[1]))
            pkeoet_server_ptest_list.append(float(l[2]))
            pkeoet_server_total_list.append(float(l[2]))

len(c_num_list)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 7
#       4 pkeoet_server_ptest_list = []
#       5 pkeoet_server_total_list = []
# ----> 7 with open(pkeoet_server_log, 'r') as f1:
#       8     for line in f1.readlines():
#       9         if line[0] != 'C':
#
# File ~/.local/lib/python3.10/site-packages/IPython/core/interactiveshell.py:284, in _modified_open(file, *args, **kwargs)
#     277 if file in {0, 1, 2}:
#     278     raise ValueError(
#     279         f"IPython won't let you open fd={file} by default "
#     280         "as it is likely to crash IPython. If you know what you are doing, "
#     281         "you can use builtins' open."
#     282     )
# --> 284 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'output/log_server.txt'

# %%
y_pkeoet_server_enc = np.array(pkeoet_server_enc_list)
y_pkeoet_server_pt = np.array(pkeoet_server_ptest_list)
y_pkeoet_server_total = np.array(pkeoet_server_total_list)
y_pkeoet_pt = np.array(pkeoet_ptest_list)

plt.xlabel('Ciphertext Num')
plt.ylabel('Time')
# print(y_pkeoet_pt)

plt.plot(x, y_pkeoet_pt, color='green', label='Pkeoet PTest Time')
plt.plot(x, y_pkeoet_server_pt, color='orange', label='Pkeoet Server PTest Time')

plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 11
#       8 # print(y_pkeoet_pt)
#      10 plt.plot(x, y_pkeoet_pt, color='green', label='Pkeoet PTest Time')
# ---> 11 plt.plot(x, y_pkeoet_server_pt, color='orange', label='Pkeoet Server PTest Time')
#      13 plt.legend()
#      14 plt.show()
#
# File /usr/lib/python3/dist-packages/matplotlib/pyplot.py:2757, in plot(scalex, scaley, data, *args, **kwargs)
#    2755 @_copy_docstring_and_deprecators(Axes.plot)
#    2756 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2757     return gca().plot(
#    2758         *args, scalex=scalex, scaley=scaley,
#    2759         **({"data": data} if data is not None else {}), **kwargs)
#
# File /usr/lib/python3/dist-packages/matplotlib/axes/_axes.py:1632, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1390 """
#    1391 Plot y versus x as lines and/or markers.
#    1392
#    (...)
#    1629 (``'green'``) or hex strings (``'#008000'``).
#    1630 """
#    1631 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1632 lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1633 for line in lines:
#    1634     self.add_line(line)
#
# File /usr/lib/python3/dist-packages/matplotlib/axes/_base.py:312, in _process_plot_var_args.__call__(self, data, *args, **kwargs)
#     310     this += args[0],
#     311     args = args[1:]
# --> 312 yield from self._plot_args(this, kwargs)
#
# File /usr/lib/python3/dist-packages/matplotlib/axes/_base.py:498, in _process_plot_var_args._plot_args(self, tup, kwargs, return_kwargs)
#     495     self.axes.yaxis.update_units(y)
#     497 if x.shape[0] != y.shape[0]:
# --> 498     raise ValueError(f"x and y must have same first dimension, but "
#     499                      f"have shapes {x.shape} and {y.shape}")
#     500 if x.ndim > 2 or y.ndim > 2:
#     501     raise ValueError(f"x and y can be no greater than 2D, but have "
#     502                      f"shapes {x.shape} and {y.shape}")
#
# ValueError: x and y must have same first dimension, but have shapes (906,) and (0,)
